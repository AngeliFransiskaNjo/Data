# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow==3.0.0
# Out:
# ...
#      ---------------------------------------- 9.9/9.9 MB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for pillow
# Failed to build pillow
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 10.1.0
#     Uninstalling Pillow-10.1.0:
#       Successfully uninstalled Pillow-10.1.0
#   Running setup.py install for pillow: started
#   Running setup.py install for pillow: finished with status 'error'
#   Rolling back uninstall of Pillow
#   Moving to c:\users\angeli fransiska njo\anaconda3\lib\site-packages\pil\
#    from C:\Users\ANGELI FRANSISKA NJO\anaconda3\Lib\site-packages\~il
#   Moving to c:\users\angeli fransiska njo\anaconda3\lib\site-packages\pillow-10.1.0.dist-info\
#    from C:\Users\ANGELI FRANSISKA NJO\anaconda3\Lib\site-packages\~illow-10.1.0.dist-info
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
from PIL import Image

im = Image.open('mix.jpg') # Can be many different formats.
pix = im.load()
print im.size  # Get the width and hight of the image for iterating over
print pix[0,0]  # Get the RGBA Value of the a pixel of an image
pix[0,0] = value  # Set the RGBA Value of the image (tuple)
im.save('mixbaru.png')  # Save the modified pixels as .png
# Out:
#   Cell In[3], line 5
#     print im.size  # Get the width and hight of the image for iterating over
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(im.size  # Get the width and hight of the image for iterating over)?

# %%
install PIL
# Out:
#   Cell In[3], line 1
#     install PIL
#             ^
# SyntaxError: invalid syntax

# %%
from PIL import Image
im = Image.open('mix.jpg', 'r')
width, height = im.size
pixel_values = list(im.getdata())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from PIL import Image
#       2 im = Image.open('mix.jpg', 'r')
#       3 width, height = im.size
#
# ModuleNotFoundError: No module named 'PIL'
